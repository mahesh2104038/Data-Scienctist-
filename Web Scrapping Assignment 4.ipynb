# %% [markdown]
# Q1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.5.0-py3-none-any.whl (995 kB)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\mahes\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Collecting trio~=0.17
#   Using cached trio-0.22.0-py3-none-any.whl (384 kB)
# Collecting trio-websocket~=0.9
#   Using cached trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\mahes\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: sniffio in c:\users\mahes\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\mahes\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Collecting outcome
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting exceptiongroup>=1.0.0rc9
#   Using cached exceptiongroup-1.0.0rc9-py3-none-any.whl (12 kB)
# Requirement already satisfied: sortedcontainers in c:\users\mahes\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\mahes\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\mahes\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Collecting async-generator>=1.9
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: pycparser in c:\users\mahes\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\mahes\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.0.0rc9 h11-0.14.0 outcome-1.2.0 selenium-4.5.0 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
url=('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')
driver.get(url)

# %%
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")

# %%
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("_")

# %%
try:
    for i in driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[3]'):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("_")

# %%
try:
    for i in driver.find_elements(By.XPATH,' //table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]'):
        Upload_date.append(i.text)
except NoSuchElementException:
    Upload_date.append('-')

# %%
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("_")

# %%
YT_list = pd.DataFrame({})
YT_list['Rank']=Rank
YT_list['Name']=Name
YT_list['Artist']=Artist
YT_list['Upload Date']=Upload_date
YT_list['Views']=Views

# %%
YT_list

# %%
driver.close()

# %% [markdown]
# Q2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
url=('https://www.bcci.tv/')
driver.get(url)

# %%
International = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a') # click button
International.click()

# %%
Name=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
#Scrapping Name
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]'):
        Name.append(i.text.replace('-',""))
except NoSuchElementException:
    Name.append('-')

# %%
#Scrapping Series
try:
    
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding"]'):
        Series.append(i.text)
except NoSuchElementException:
    Series.append('-')

# %%
#scrapping Place
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]'):
        Place.append(i.text)
except NoSuchElementException:
    Place.append('-')

# %%
#Scrapping Date
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]'):
        Date.append(i.text)
except NoSuchElementException:
    Date.append('-')

# %%
#Scrapping Time
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]'):
        Time.append(i.text.replace('IST',""))
except NoSuchElementException:
    Time.append('-')

# %%
BCCI=pd.DataFrame({})
BCCI['Title']=Series
BCCI['Name']=Name
BCCI['Place']=Place
BCCI['Date']=Date
BCCI['Time']=Time
BCCI
# Out:
#                                     Title       Name  \
# 0  ICC T20 WORLD CUP WARM-UP MATCHES 2022  1st T20I
# 1  ICC T20 WORLD CUP WARM-UP MATCHES 2022  2nd T20I
# 2             ICC MENS T20 WORLD CUP 2022  1st T20I
# 3             ICC MENS T20 WORLD CUP 2022  2nd T20I
# 4             ICC MENS T20 WORLD CUP 2022  3rd T20I
# 5             ICC MENS T20 WORLD CUP 2022  4th T20I
# 6             ICC MENS T20 WORLD CUP 2022  5th T20I
#
#                        Place         Date       Time
# 0                 The Gabba,  17 OCT 2022   9:30 AM
# 1                 The Gabba,  19 OCT 2022   1:30 PM
# 2  Melbourne Cricket Ground,  23 OCT 2022   1:30 PM
# 3     Sydney Cricket Ground,  27 OCT 2022  12:30 PM
# 4             Perth Stadium,  30 OCT 2022   4:30 PM
# 5             Adelaide Oval,   2 NOV 2022   1:30 PM
# 6  Melbourne Cricket Ground,   6 NOV 2022   1:30 PM

# %% [markdown]
# # Q3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/ You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Let first connect to the driver

driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
driver.get("https://www.guru99.com/")
driver.maximize_window()

# %%
# Click Selenium Button
Selenium = driver.find_element(By.XPATH,'//*[@id="java_technologies"]/li[3]/a') # click button
try:
    Selenium.click()
except ElementNotInteractableException:#handling element not clickable exception
    driver.get(Selenium.get_attribute('href'))
time.sleep(3)

# %%
# Click selenium exception handling  Button
exception_handling = driver.find_element(By.XPATH,"//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handling.click()
except ElementNotInteractableException:  #if the above code doesn't work/is not clickable then, the below code will handle it
    driver.get(exception_handling.get_attribute('href'))

# %%
name=[]
description=[]
#Scrapping Name
for i in driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]/p/strong'):
    if 'Exception:' in i.text:
        name.append(i.text[3:-1])
for i in driver.find_elements(By.XPATH,'//*[@id="post-1953"]/div/div/p'):
    if 'Exception:' in i.text:
        description.append(i.text.split(' ',2)[2])

# %%
Selenium_Exception=pd.DataFrame()
Selenium_Exception['Exception name']=name
Selenium_Exception['Description']=description
Selenium_Exception
# Out:
#                           Exception name  \
# 0             ElementNotVisibleException
# 1          ElementNotSelectableException
# 2                 NoSuchElementException
# 3                   NoSuchFrameException
# 4                NoAlertPresentException
# 5                  NoSuchWindowException
# 6         StaleElementReferenceException
# 7               SessionNotFoundException
# 8                       TimeoutException
# 9                     WebDriverException
# 10             ConnectionClosedException
# 11      ElementClickInterceptedException
# 12       ElementNotInteractableException
# 13              ErrorInResponseException
# 14   ErrorHandler.UnknownServerException
# 15          ImeActivationFailedException
# 16              ImeNotAvailableException
# 17          InsecureCertificateException
# 18              InvalidArgumentException
# 19          InvalidCookieDomainException
# 20           InvalidCoordinatesException
# 21          InvalidElementStateException
# 22             InvalidSessionIdException
# 23        InvalidSwitchToTargetException
# 24                   JavascriptException
# 25                         JsonException
# 26              NoSuchAttributeException
# 27        MoveTargetOutOfBoundsException
# 28                NoSuchContextException
# 29                 NoSuchCookieException
# 30                     NotFoundException
# 31           RemoteDriverServerException
# 32                   ScreenshotException
# 33            SessionNotCreatedException
# 34            UnableToSetCookieException
# 35            UnexpectedTagNameException
# 36               UnhandledAlertException
# 37       UnexpectedAlertPresentException
# 38                UnknownMethodException
# 39           UnreachableBrowserException
# 40           UnsupportedCommandException
#
#                                           Description
# 0   This type of Selenium exception occurs when an...
# 1   This Selenium exception occurs when an element...
# 2   This Exception occurs if an element could not ...
# 3   This Exception occurs if the frame target to b...
# 4   This Exception occurs when you switch to no pr...
# 5   This Exception occurs if the window target to ...
# 6   This Selenium exception occurs happens when th...
# 7   The WebDriver is acting after you quit the bro...
# 8   Thrown when there is not enough time for a com...
# 9   This Exception takes place when the WebDriver ...
# 10  This type of Exception takes place when there ...
# 11  The command may not be completed as the elemen...
# 12  This Selenium exception is thrown when any ele...
# 13  This happens while interacting with the Firefo...
# 14  Exception is used as a placeholder in case if ...
# 15  This expectation will occur when IME engine ac...
# 16    It takes place when IME support is unavailable.
# 17  Navigation made the user agent to hit a certif...
# 18  It occurs when an argument does not belong to ...
# 19  This happens when you try to add a cookie unde...
# 20  This type of Exception matches an interacting ...
# 21  It occurs when command can’t be finished when ...
# 22  This Exception took place when the given sessi...
# 23  This occurs when the frame or window target to...
# 24  This issue occurs while executing JavaScript g...
# 25  It occurs when you afford to get the session w...
# 26  This kind of Exception occurs when the attribu...
# 27  It takes place if the target provided to the A...
# 28           ContextAware does mobile device testing.
# 29  This Exception occurs when no cookie matching ...
# 30  This Exception is a subclass of WebDriverExcep...
# 31  This Selenium exception is thrown when the ser...
# 32            It is not possible to capture a screen.
# 33  It happens when a new session could not be suc...
# 34  This occurs if a driver is unable to set a coo...
# 35  Happens if a support class did not get a web e...
# 36  This expectation occurs when there is an alert...
# 37  It occurs when there is the appearance of an u...
# 38  This Exception happens when the requested comm...
# 39  This Exception occurs only when the browser is...
# 40  This occurs when remote WebDriver doesn’t send...

# %%
driver.close()

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Let first connect to the driver

driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
driver.get('https://github.com/trending')

# %%
# Scraping repositories URL
URL= []
link=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]/a')
for i in link:
    URL.append(i.get_attribute('href'))

# %%
# Creating Empty list for Scraping Data
Title=[]
Description=[]
Count =[]
Language =[]

# %%
# Scraping Repositority Title
Title=[]
try:
    title=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
    for i in title:
        Title.append(i.text)
except NoSuchElementException:
    Title.append('NA')

# %%
# Scraping Description
Description=[]
for i in tqdm(URL):
    driver.get(i)
    time.sleep(2)
    try:
        description=driver.find_element(By.XPATH,'//p[@class="f4 my-3"]')
        Description.append(description.text)
    except NoSuchElementException:
        Description.append('NA')
print(len(Description))
Description
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [01:56<00:00,  4.66s/it]
# 25
# ['Holberton-style C code checker written in Perl',
#  'An open-source C++ library developed and used at Facebook.',
#  'ASP.NET Core is a cross-platform .NET framework for building modern cloud-based web applications on Windows, Mac, or Linux.',
#  'Preguntas típicas sobre React para entrevistas de trabajo ⚛️',
#  '润学全球官方指定GITHUB，整理润学宗旨、纲领、理论和各类润之实例；解决为什么润，润去哪里，怎么润三大问题； 并成为新中国人的核心宗教，核心信念。',
#  'These are the best resources for System Design on the Internet',
#  'Projeto desenvolvido durante o Ignite Lab 03',
#  'Reproduce DeFi hack incidents using Foundry.',
#  '科技爱好者周刊，每周五发布',
#  'Generate images by NovelAI | 基于 NovelAI 的画图机器人',
#  'A proof of concept exploit for CVE-2022-40684 affecting Fortinet FortiOS, FortiProxy, and FortiSwitchManager',
#  "An open-source Chinese font derived from Fontworks' Klee One. 一款开源中文字体，基于 FONTWORKS 出品字体 Klee One 衍生。",
#  'A repo of small demos that assemble some of the well-known design patterns in Unity development to support the ebook "Level up your code with game programming patterns"',
#  'NA',
#  'A collection of TypeScript/JavaScript packages to build high-quality web services.',
#  'notes for prompt engineering',
#  'Component infrastructure and Material Design components for Angular',
#  'A progressive Node.js framework for building efficient, scalable, and enterprise-grade server-side applications on top of TypeScript & JavaScript (ES6, ES7, ES8) 🚀',
#  'You can use this version to experience how novelai works without a good gpu.',
#  '.NET MAUI is the .NET Multi-platform App UI, a framework for building native device applications spanning mobile, tablet, and desktop.',
#  '📋 React Hooks for form state management and validation (Web + React Native)',
#  'Always know what to expect from your data.',
#  '🐬 A collection of awesome resources for the Flipper Zero device.',
#  'Low cost USB3.2Gen1 HDMI-USB Video Acquisition With Loop Out (Loop Out HDMI Capture Card) base on MS2130 & MS9332',
#  'Learn how to design large-scale systems. Prep for the system design interview. Includes Anki flashcards.']

# %%
# Scraping Contributor count
Count =[]
for i in tqdm(URL):
    driver.get(i)
    time.sleep(1)
    try:
        count=driver.find_element(By.XPATH,"//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Count.append(count.text)
    except NoSuchElementException:
        Count.append('NA')
print(len(Count))
Count
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [01:16<00:00,  3.05s/it]
# 25
# ['8',
#  '691',
#  '1,076',
#  '16',
#  '74',
#  '5',
#  'NA',
#  '15',
#  '32',
#  '5',
#  'NA',
#  '5',
#  'NA',
#  '2',
#  '20',
#  '2',
#  '642',
#  '341',
#  'NA',
#  '456',
#  '244',
#  '310',
#  '25',
#  'NA',
#  '115']

# %%
# Scraping Language
Language =[]
for i in tqdm(URL):
    driver.get(i)
    time.sleep(1)
    L =[]
    try:
        lang=driver.find_elements(By.XPATH,"//li[@class='d-inline']//a//span[1]")
        if lang:
            for j in lang:
                L.append(j.text)
        else:
            L.append('NA')
        Language.append(L)
    except NoSuchElementException:
        Language.append('NA')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [01:26<00:00,  3.47s/it]

# %%
print(len(Language))
Language
# Out:
# 25
# [['Perl', 'C', 'Shell'],
#  ['C++', 'Python', 'CMake', 'C', 'Cython', 'Assembly'],
#  ['C#', 'JavaScript', 'HTML', 'C++', 'TypeScript', 'Java'],
#  ['JavaScript'],
#  ['NA'],
#  ['NA'],
#  ['TypeScript', 'JavaScript', 'HTML', 'CSS'],
#  ['Solidity'],
#  ['NA'],
#  ['TypeScript'],
#  ['Python'],
#  ['Batchfile', 'Python'],
#  ['C#', 'ShaderLab'],
#  ['Rust'],
#  ['JavaScript', 'TypeScript', 'Shell'],
#  ['NA'],
#  ['TypeScript', 'HTML', 'SCSS', 'Starlark', 'JavaScript', 'CSS', 'Shell'],
#  ['TypeScript'],
#  ['Jupyter Notebook'],
#  ['C#', 'PowerShell', 'Java', 'Shell', 'HTML', 'CSS'],
#  ['TypeScript', 'JavaScript'],
#  ['Python', 'Jupyter Notebook', 'Jinja', 'JavaScript', 'HTML', 'CSS'],
#  ['NA'],
#  ['NA'],
#  ['Python', 'Shell']]

# %%
Github=pd.DataFrame({'Title':Title[:25],'Description':Description,
                'Contributors_count':Count,'Language_used':Language})
print('\033[1m'+'GitHub Trending Repository :'+'\033[0m')
Github
# Out:
# GitHub Trending Repository :
#                                                 Title  \
# 0                             holbertonschool / Betty
# 1                                    facebook / folly
# 2                                 dotnet / aspnetcore
# 3                midudev / preguntas-entrevista-react
# 4               The-Run-Philosophy-Organization / run
# 5            InterviewReady / system-design-resources
# 6     rocketseat-education / ignite-lab-design-system
# 7                           SunWeb3Sec / DeFiHackLabs
# 8                                     ruanyf / weekly
# 9                              koishijs / novelai-bot
# 10                        horizon3ai / CVE-2022-40684
# 11                                  lxgw / LxgwWenKai
# 12  Unity-Technologies / game-programming-patterns...
# 13       smallnest / concurrency-programming-via-rust
# 14                                       toss / slash
# 15                                 sw-yx / prompt-eng
# 16                               angular / components
# 17                                      nestjs / nest
# 18                      JingShing / novelai-colab-ver
# 19                                      dotnet / maui
# 20                  react-hook-form / react-hook-form
# 21            great-expectations / great_expectations
# 22                      djsime1 / awesome-flipperzero
# 23                         YuzukiHD / YuzukiLOHCC-PRO
# 24                 donnemartin / system-design-primer
#
#                                           Description Contributors_count  \
# 0      Holberton-style C code checker written in Perl                  8
# 1   An open-source C++ library developed and used ...                691
# 2   ASP.NET Core is a cross-platform .NET framewor...              1,076
# 3   Preguntas típicas sobre React para entrevistas...                 16
# 4   润学全球官方指定GITHUB，整理润学宗旨、纲领、理论和各类润之实例；解决为什么润，润去哪里...                 74
# 5   These are the best resources for System Design...                  5
# 6        Projeto desenvolvido durante o Ignite Lab 03                 NA
# 7        Reproduce DeFi hack incidents using Foundry.                 15
# 8                                       科技爱好者周刊，每周五发布                 32
# 9      Generate images by NovelAI | 基于 NovelAI 的画图机器人                  5
# 10  A proof of concept exploit for CVE-2022-40684 ...                 NA
# 11  An open-source Chinese font derived from Fontw...                  5
# 12  A repo of small demos that assemble some of th...                 NA
# 13                                                 NA                  2
# 14  A collection of TypeScript/JavaScript packages...                 20
# 15                       notes for prompt engineering                  2
# 16  Component infrastructure and Material Design c...                642
# 17  A progressive Node.js framework for building e...                341
# 18  You can use this version to experience how nov...                 NA
# 19  .NET MAUI is the .NET Multi-platform App UI, a...                456
# 20  📋 React Hooks for form state management and va...                244
# 21         Always know what to expect from your data.                310
# 22  🐬 A collection of awesome resources for the Fl...                 25
# 23  Low cost USB3.2Gen1 HDMI-USB Video Acquisition...                 NA
# 24  Learn how to design large-scale systems. Prep ...                115
#
#                                         Language_used
# 0                                    [Perl, C, Shell]
# 1           [C++, Python, CMake, C, Cython, Assembly]
# 2       [C#, JavaScript, HTML, C++, TypeScript, Java]
# 3                                        [JavaScript]
# 4                                                [NA]
# 5                                                [NA]
# 6                 [TypeScript, JavaScript, HTML, CSS]
# 7                                          [Solidity]
# 8                                                [NA]
# 9                                        [TypeScript]
# 10                                           [Python]
# 11                                [Batchfile, Python]
# 12                                    [C#, ShaderLab]
# 13                                             [Rust]
# 14                    [JavaScript, TypeScript, Shell]
# 15                                               [NA]
# 16  [TypeScript, HTML, SCSS, Starlark, JavaScript,...
# 17                                       [TypeScript]
# 18                                 [Jupyter Notebook]
# 19           [C#, PowerShell, Java, Shell, HTML, CSS]
# 20                           [TypeScript, JavaScript]
# 21  [Python, Jupyter Notebook, Jinja, JavaScript, ...
# 22                                               [NA]
# 23                                               [NA]
# 24                                    [Python, Shell]

# %%
driver.close()

# %% [markdown]
# # Q6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/ You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Let first connect to the driver

driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
# Getting the webpage of mentioned url 
driver.get('https://www.billboard.com/')

# %%
#Clicking on charts
charts=driver.find_element(By.XPATH,'//*[@id="mega-menu-item-charts"]/a')
charts.click()

# %%
# Creating empty lists
Song_Name = []
Artist_Name = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# %%
# Scraping name
for i in driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]'):
    Song_Name.append(i.text)
len(Song_Name)
# Out:
# 100

# %%
#Scrappin Artist name 1 st one
Artist_Name.append(driver.find_element(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']").text)

# %%
#Remainig Artist Name
artistTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
Artist_Name.extend([i.text for i in artistTag])

# %%
#Scapping Rank
rank=[]
rankTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet']")
rank.extend([i.text for i in rankTag[:3]])

# %%
#Remaining RAnk
Rank=[]
RankTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
Rank.extend([i.text for i in RankTag])

# %%
# removing ''
for i in Rank:
    if i=='':
        Rank.remove(i)

# %%
# slicing as per requirement
lastweekpos=Rank[0::3]
lastweekpos.insert(0,rank[0])
peakPos=Rank[1::3]
peakPos.insert(0,rank[1])
weeksonBoard=Rank[2::3]
weeksonBoard.insert(0,rank[2])

# %%
#check length of all
len(Song_Name),len(Artist_Name),len(lastweekpos),len(peakPos),len(weeksonBoard)
# Out:
# (100, 100, 133, 133, 133)

# %%
# Create Dataframe
df=pd.DataFrame()
df['SongName']=Song_Name[0:100]
df['ArtistName']=Artist_Name
df['Last Week']=lastweekpos[0:100]
df["PeekPosition"]=peakPos[0:100]
df['Weeks On board']=weeksonBoard[0:100]
df
# Out:
#                                              SongName  \
# 0                     Bad Habit\nSteve Lacy\n1\n1\n14
# 1             Unholy\nSam Smith & Kim Petras\n3\n2\n2
# 2                   As It Was\nHarry Styles\n2\n1\n27
# 3   I Like You (A Happier Song)\nPost Malone Featu...
# 4               Sunroof\nNicky Youre & dazy\n5\n4\n19
# ..                                                ...
# 95     Gotta Move On\nDiddy & Bryson Tiller\n-\n96\n1
# 96                 Forget Me\nLewis Capaldi\n-\n97\n1
# 97                Down Home\nJimmie Allen\n100\n98\n2
# 98          What He Didn't Do\nCarly Pearce\n-\n99\n1
# 99                              Talk\nYeat\n93\n42\n5
#
#                         ArtistName Last Week PeekPosition Weeks On board
# 0                       Steve Lacy
# 1           Sam Smith & Kim Petras         3            2              2
# 2                     Harry Styles         2            1             27
# 3   Post Malone Featuring Doja Cat         4            3             18
# 4               Nicky Youre & dazy         5            4             19
# ..                             ...       ...          ...            ...
# 95           Diddy & Bryson Tiller
# 96                   Lewis Capaldi        78           78              5
# 97                    Jimmie Allen
# 98                    Carly Pearce        85           83              4
# 99                            Yeat
#
# [100 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/hr-recruiters-consultants You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
# Let first connect to the driver

driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
# Getting the webpage of mentioned url 
url = "https://www.naukri.com/"
driver.get(url)

# %%
#Fetching urls to navigate recruiter page
recruiter = driver.find_element(By.XPATH,'//a[@title="Search Jobs"]')
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
# Fetching search button, sending keys and clicking on it
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[1]/div/div/div/input") 
search.send_keys("Data science ")           
btn = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]').click()     
time.sleep(3)

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

# %%
#Scraping data of Names
for i in driver.find_elements(By.XPATH,"//div[@class='job-description fs12 grey-text']"):
    Name.append(i.text)
time.sleep(3)

#Scraping data of Designation
for i in driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']"):
    Designation.append(i.text)
    
#Scraping data of company name
for i in driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']"):
    Company.append(i.text)

#Scraping data of locations
for i in driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft']"):
    Location.append(i.text)
time.sleep(3)

#Scraping data of skills
for i in driver.find_elements(By.XPATH,"//ul[@class='tags has-description']"):
    Skills.append(i.text)

# %%
print(len(Name),len(Designation),len(Company),len(Location),len(Skills))
# Out:
# 20 20 20 37 20

# %%
# Creating dataframe for scraped data
Naukri=pd.DataFrame({})
Naukri['Name'] = Name[0:20]
Naukri['Designation'] = Designation[0:20]
Naukri['Company'] = Company[0:20]
Naukri['Location'] = Location[0:20]
Naukri['Skills']=Skills[0:20]
Naukri
# Out:
#                                                  Name  \
# 0   Skill required: Data Science - Predictive Mode...
# 1   Skill required: Data Science - Predictive Mode...
# 2   The ideal candidate should have a strong clien...
# 3   Bachelor s degree in an analytical field such ...
# 4   Bachelors (4 year) degree in statistics, appli...
# 5   Work with OMICs, image, med device and RWE dat...
# 6   • Collect data on consumers, competitors & mar...
# 7   Proficient in debugging software using Python ...
# 8   Institute company A / B testing framework and ...
# 9   Preferred experience in machine learning, neur...
# 10  Experience building and deploying pipelines fo...
# 11  Experience building and deploying pipelines fo...
# 12  Experience building and deploying pipelines fo...
# 13  Experience building and deploying pipelines fo...
# 14  Experience building and deploying pipelines fo...
# 15  Experience building and deploying pipelines fo...
# 16  Bachelors in STEM Must have 5+ years experienc...
# 17  Forecast series and impact of shifts in market...
# 18  Bachelor of Engineering Good verbal & written ...
# 19  Asthe successful candidate, you will hold an a...
#
#                                           Designation  \
# 0                         Senior Analyst-Data Science
# 1                         Senior Analyst-Data Science
# 2   ACN - Applied Intelligence - Finance - Data Sc...
# 3                           Sr. Manager, Data Science
# 4            Senior Analyst, Data Science & Analytics
# 5                    Assistant Manager - Data Science
# 6               Market Research / Data Science Intern
# 7                                Data Science/Analyst
# 8   Data Science Engineer (Synthetic Data Generation)
# 9   Bosch Hiring For Data science Engineers @ Bang...
# 10                          Data Science Engineer 5.1
# 11                          Data Science Engineer 4.4
# 12                          Data Science Engineer 4.3
# 13                          Data Science Engineer 5.1
# 14                          Data Science Engineer 4.4
# 15                          Data Science Engineer 4.3
# 16                        Data Analyst - Data Science
# 17                            Sr Data Science Analyst
# 18                                       Data Science
# 19         Technical Expert - Industrial Data Science
#
#                                Company  \
# 0                            Accenture
# 1                            Accenture
# 2                            Accenture
# 3                                 Visa
# 4                           Transunion
# 5                           Citiustech
# 6                          Mind A Mend
# 7                          Myfuturejob
# 8                              Calsoft
# 9   Bosch Global Software Technologies
# 10                                 ANZ
# 11                                 ANZ
# 12                                 ANZ
# 13                                 ANZ
# 14                                 ANZ
# 15                                 ANZ
# 16                           Altigreen
# 17                          Transunion
# 18                             Infosys
# 19                             Siemens
#
#                                   Location  \
# 0                 Data Science & Analytics
# 1              Engineering - Software & QA
# 2   Customer Success, Service & Operations
# 3                                    Other
# 4                         Work from office
# 5                   Temp. WFH due to covid
# 6                   Permanent Remote / WFH
# 7                                   Hybrid
# 8                      Bangalore/Bengaluru
# 9                              Delhi / NCR
# 10                        Gurgaon/Gurugram
# 11                      Mumbai (All Areas)
# 12                               0-3 Lakhs
# 13                               3-6 Lakhs
# 14                              6-10 Lakhs
# 15                             10-15 Lakhs
# 16                             Foreign MNC
# 17                               Corporate
# 18                              Indian MNC
# 19                                 Startup
#
#                                                Skills
# 0   Publishing\nConsulting\nPredictive modeling\nD...
# 1   Publishing\nConsulting\nPredictive modeling\nD...
# 2   Computer science\nData analysis\nHealthcare\nS...
# 3   Spark\nMicroStrategy\nKafka\nPower BI\nAirflow...
# 4   IT Skills\nPython\nMachine Learning\nCloud\nPr...
# 5   Data Science\nNLP\nMachine Learning\nDeep Lear...
# 6   Operations\nMarket Research\nData Science\nCom...
# 7   Computer science\nData analysis\nUsage\nDebugg...
# 8                       data science\ndata collection
# 9   Data Science\npython\nMachine Learning\nR Prog...
# 10  Statistical modeling\nData management\ndata sc...
# 11  Statistical modeling\nData management\ndata sc...
# 12  Statistical modeling\nData management\ndata sc...
# 13  Statistical modeling\nData management\ndata sc...
# 14  Statistical modeling\nData management\ndata sc...
# 15  Statistical modeling\nData management\ndata sc...
# 16  Data analysis\nBusiness Analyst\ndata science\...
# 17  Ab Initio\ndata science\nBi Tools\nstatistical...
# 18  Python\nBigdata\nAzure\nAlgorithms\nwritten co...
# 19  Operations research\nPublishing\nData manageme...

# %%
driver.close()

# %% [markdown]
# # Q8. Scrape the details of Highest selling novels.
# URL = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare
#
# You have to find the following details:
#
# A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
# get webpage
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
#Creating empty list
Bookname = []
Authorname = []
Volumessold = []
Publisher = []
Genre = []

# %%
#scraping book names data
for i in driver.find_elements(By.XPATH,"//tbody//tr/td[2]"):
    Bookname.append(i.text)
    
#Scraping author names data
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Authorname.append(i.text)
    except NoSuchElementException:
        Authorname.append('-')
time.sleep(1)

#Scraping data of volumes sold
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[4]"):
    Volumessold.append(i.text)
    
#Scraping data of publisher names
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[5]"):
    Publisher.append(i.text)
    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[6]"):
    Genre.append(i.text)

# %%
#Creating dataframe for scraped data
Novels=pd.DataFrame({})
Novels['Book Name'] = Bookname
Novels['Author'] = Authorname
Novels['Volume sold'] = Volumessold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
# get webpage
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

#Scraping data of Names
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)
    
#Scraping data of Year span
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)
    
#Scraping data of Run time
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)
    
#Scraping data of Ratings
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)
    
#Scraping data of votes
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)

# %%
# Creating dataframe for scraped data
df=pd.DataFrame({})
df['Name'] = Name
df['Year Span'] = Year_span
df['Genre'] = Genre
df['Run Time'] = Run_time
df['Ratings'] = Ratings
df['Votes'] = Votes
df
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,067,439
# 1    51 min     8.7  1,159,897
# 2    44 min     8.1    974,862
# 3    60 min     7.5    290,456
# 4    43 min     7.6    249,751
# ..      ...     ...        ...
# 95   42 min     7.4     49,782
# 96   50 min     7.8     60,858
# 97   42 min     8.1    195,973
# 98   45 min     7.1     41,241
# 99  572 min     8.6    239,642
#
# [100 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/ You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"C:\Users\mahes\Downloads\chromedriver.exe")

# %%
# get webpage
driver.get(" https://archive.ics.uci.edu/")

# %%
# Finding view all dataset button from the webpage
viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")    
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)

# %%
# Fetching page urls of all datasets 
view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
list_url = view_list.get_attribute("href")           
driver.get(list_url)

# %%
# Fetching urls for each dataset
dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")

# %%
urls = []     
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
#Creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

# %%
for i in urls[0:100]:
    driver.get(i)
    time.sleep(2)
    
    #Scraping Dataset name
    try: 
        dataset_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    
    
    #Scraping data type
    try:
        data_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    
    
    #scraping Task
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    
    # Scraping Attribute type
    try:
        attribute_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    
    
    # Scraping No of instances
    try:
        instances = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    
    
    # Scraping No of attributes
    try:
        attribute = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    
    
    # Scraping year
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')

# %%
# Creating dataframe 

df=pd.DataFrame({})
df['Data Name'] = Dataset_name[:622]
df['Data Type'] = Data_type[:622]
df['Task'] = Task[:622]
df['Attribute type'] = Attribute_type[:622]
df['No of instance'] = No_of_instances[:622]
df['No of attributes'] = No_of_attributes[:622]
df['Year'] = Year[:622]
df
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 195             Cervical Cancer Behavior Risk Data Set
# 196       Challenger USA Space Shuttle O-Ring Data Set
# 197                     Character Font Images Data Set
# 198                    Character Trajectories Data Set
# 199   Chemical Composition of Ceramic Samples Data Set
#
#                      Data Type                        Task Attribute type  \
# 0                 Multivariate              Classification           Real
# 1             Sequential, Text      Regression, Clustering           Real
# 2    Multivariate, Time-Series  Classification, Clustering  Integer, Real
# 3                   Sequential  Classification, Regression           Real
# 4                 Multivariate  Classification, Clustering              -
# ..                         ...                         ...            ...
# 195   Multivariate, Univariate  Classification, Clustering        Integer
# 196               Multivariate                  Regression        Integer
# 197               Multivariate              Classification  Integer, Real
# 198                Time-Series  Classification, Clustering           Real
# 199               Multivariate  Classification, Clustering           Real
#
#     No of instance No of attributes  Year
# 0             7840                5  2018
# 1           434874                4  2013
# 2             1984                8  2019
# 3           158716                4  2021
# 4              232               16  2020
# ..             ...              ...   ...
# 195             72               19  2019
# 196             23                4  1993
# 197         745000              411  2016
# 198           2858                3  2008
# 199             88               19  2019
#
# [200 rows x 7 columns]

# %%
driver.close()
